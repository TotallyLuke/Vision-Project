# %% [markdown]
# # Project on Vehicle counting
#
# In partial fulfillment for the Vision and Cognitive Services exam (MSc in CompSci @ Math.UniPd)
#
# by Luca Veronese and Shakiba Farjood Fashalami

# %% [markdown]
# # Configuration

# %% [markdown]
# ## Import libraries

# %% [markdown]
# Here we build and install the necessary packages (if they are not installed).

# %%
# !pip install numpy --quiet

# %%
# !pip install opencv-python --quiet

# %%
# !pip install matplotlib --quiet

# %%
# !pip install scikit-learn --quiet

# %%
# !pip install torch torchvision --quiet

# %%
# !pip install tracker --quiet

# %% [markdown]
# We import the libraries in the namespace.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import collections
import numpy.typing as npt
import os
import sys
from PIL import Image as im
from tqdm.notebook import tqdm

# %% [markdown]
# When running the notebook in Colab, we need the following cell because Google forbid the execution of `cv2.imshow` function for security reasons.

# %%
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from google.colab.patches import cv2_imshow
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
def safe_cv2_imshow(image: cv2.VideoCapture, label: str = '', time: int = 1000) -> None:
    """
    Invoke `cv2_imshow` or `cv2.imshow` depending on whether we are running the notebook in GColab or Jupyter
    Args:
        image: an OpenCV VideoCapture object
        label: image's title
        time: when using Jupyter, ms the window will remain active
    """
    if 'google.colab' in str(get_ipython()):
        cv2_imshow(image)
    else:
        # cv2.imshow(label, image)
        # cv2.waitKey(time)
        # cv2.destroyAllWindows()
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.title(label)
        plt.axis('off')
        plt.show()

# %% [markdown]
# ## Import video

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
SOURCE_FOLDER = f"/home/lucav/Documents/Master/vcs/project"
# SOURCE_FOLDER = f"/content/gdrive/MyDrive/videos/"
SOURCE_FILE_NAME = f"test1.mp4"
SOURCE_VIDEO_PATH = f"{SOURCE_FOLDER}/{SOURCE_FILE_NAME}"
train_video = cv2.VideoCapture(SOURCE_VIDEO_PATH)

# %%
## Alternative to previous 2 cells:

# from google.colab import drive
# drive.mount('/content/gdrive')
# train_video = cv2.VideoCapture('/content/gdrive/MyDrive/videos/test1.mp4')

# %% [markdown]
# Let's check if the video import was successful and display the first frame if it is the case.

# %%
retval, frame = train_video.read()

if retval is False:
    print("Error reading the video file.")
else:
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    safe_cv2_imshow(frame)
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/lucav/Documents/Master/vcs/project/venv/lib/python3.8/site-packages/cv2/qt/plugins"

# %% [markdown]
# Now we print information about the video.

# %%
TOTAL_FRAMES = int(train_video.get(cv2.CAP_PROP_FRAME_COUNT))
IMG_HEIGHT, IMG_WIDTH, _ = frame.shape

print(f"Number of frames in the video: {TOTAL_FRAMES}")
print(f"Size of each frame: {IMG_HEIGHT} * {IMG_WIDTH}")
# Out:
# Number of frames in the video: 942
# Size of each frame: 720 * 1280

# %% [markdown]
# ## Edge detection

# %% [markdown]
# We search for suitable values for low and high threshold of the Canny's edge detector.
# As we reduce both low and high thresholds, the number of detected edges increases.
# We define a mask so that we can concentrate on the bottom half of image, so that we are sure to work "under the horizon".

# %%
hough_lines = []

mask = np.zeros((IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
mask[int(IMG_HEIGHT / 2):, :] = 255


def detect_edges(blur: npt.ArrayLike, low_thresh: int, high_thresh: int, mask: npt.ArrayLike) -> np.array:
    can = cv2.Canny(blur, low_thresh, high_thresh)
    return cv2.bitwise_and(can, mask)

# %%
low_threshold = 110
high_threshold = 210

if retval is False:
    print("Video file not yet configured: cells above not runned or run with error.")
else:
    blur = cv2.GaussianBlur(frame, (13, 13), 1)
    canny_edges = np.zeros_like(blur, dtype=np.uint8)
    while np.count_nonzero(canny_edges) < 18000:
        low_threshold -= 5
        high_threshold -= 10
        canny_edges = detect_edges(blur, low_threshold, high_threshold, mask)

        print("low thresh: {}, high thresh: {}, num. of edges {}".format(low_threshold, high_threshold,
                                                                         np.count_nonzero(canny_edges)))
# Out:
# low thresh: 105, high thresh: 200, num. of edges 9328
# low thresh: 100, high thresh: 190, num. of edges 9696
# low thresh: 95, high thresh: 180, num. of edges 10207
# low thresh: 90, high thresh: 170, num. of edges 10585
# low thresh: 85, high thresh: 160, num. of edges 11165
# low thresh: 80, high thresh: 150, num. of edges 11391
# low thresh: 75, high thresh: 140, num. of edges 12256
# low thresh: 70, high thresh: 130, num. of edges 12843
# low thresh: 65, high thresh: 120, num. of edges 13401
# low thresh: 60, high thresh: 110, num. of edges 14173
# low thresh: 55, high thresh: 100, num. of edges 14877
# low thresh: 50, high thresh: 90, num. of edges 15514
# low thresh: 45, high thresh: 80, num. of edges 16407
# low thresh: 40, high thresh: 70, num. of edges 17464
# low thresh: 35, high thresh: 60, num. of edges 18908

# %%
train_video.set(cv2.CAP_PROP_POS_FRAMES, 0)
hough_lines = []

for i in range(0, 150):
    retval, frame = train_video.read()

    # Check if the frame was successfully read
    if retval is True:

        blur = cv2.GaussianBlur(frame, (13, 13), 1)
        masked_edges = detect_edges(blur, low_threshold, high_threshold, mask)

        detected_lines = cv2.HoughLinesP(masked_edges, rho=1, theta=np.pi / 200, threshold=100,
                                         minLineLength=IMG_HEIGHT / 4,
                                         maxLineGap=10)

        line_image = np.zeros_like(frame)
        for line in detected_lines:
            x1, y1, x2, y2 = line[0]
            steepness = abs((y2 - y1) / (x2 - x1)) if x1 != x2 else sys.float_info.max
            if steepness > 0.1:
                hough_lines.append(line)
                cv2.line(line_image, (x1, y1), (x2, y2), (0, 0, 255), 2)

        if i % 25 == 24:
            safe_cv2_imshow(cv2.addWeighted(frame, 0.75, line_image, 0.90, 0))

# %%
print(f"Canny's edge detector low threshold set to {low_threshold}, high threshold set to {high_threshold}")

safe_cv2_imshow(canny_edges, f"Canny l:{low_threshold} h:{high_threshold}")  #canny
# Out:
# Canny's edge detector low threshold set to 35, high threshold set to 60

# %% [markdown]
# We overlay all the Hough's lines that were detected onto a frame.

# %%
line_image = np.zeros_like(frame)
for line in hough_lines:
    x1, y1, x2, y2 = line[0]
    steepness = abs((y2 - y1) / (x2 - x1)) if x1 != x2 else sys.float_info.max
    if steepness > 0.1:
        cv2.line(line_image, (x1, y1), (x2, y2), (0, 0, 255), 2)

blended_image = cv2.addWeighted(frame, 0.75, line_image, 0.90, 0)
safe_cv2_imshow(blended_image)

# %% [markdown]
# ## Clustering edges to find regions on the road

# %%
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES, 335)
# Out:
# True

# %%
retval, frame_a = cap.read()
gray_a = cv2.cvtColor(frame_a, cv2.COLOR_BGR2GRAY)

gray_a[:438, :] = 255
gray_a[610:, :] = 255
img_a = np.copy(gray_a)

# %%
for i in range(1, 4):
    cap.set(cv2.CAP_PROP_POS_FRAMES, 380 + (5 * i))
    retval, frame_b = cap.read()
    gray = cv2.cvtColor(frame_b, cv2.COLOR_BGR2GRAY)
    gray[438:, :] = 255
    str_lab: str = f"frame {380 + (5 * i)}"
    safe_cv2_imshow(gray, str_lab, 1999)

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES, 390)
retval, frame_b = cap.read()
gray_b = cv2.cvtColor(frame_b, cv2.COLOR_BGR2GRAY)

gray_b[438:, :] = 255
gray_b[:370, :] = 255

# safe_cv2_imshow(gray, "0", 1999)

# %%
for i in range(1, 4):
    cap.set(cv2.CAP_PROP_POS_FRAMES, 430 + (5 * i))
    retval, frame_b = cap.read()
    gray = cv2.cvtColor(frame_b, cv2.COLOR_BGR2GRAY)
    gray[370:, :] = 255
    str_lab: str = f"frame {420 + (5 * i)}"
    safe_cv2_imshow(gray, str_lab, 1999)

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES, 435)
retval, frame_b = cap.read()
gray_c = cv2.cvtColor(frame_b, cv2.COLOR_BGR2GRAY)

gray_c[370:, :] = 255
gray_c[:335, :] = 255

safe_cv2_imshow(gray, "0", 1999)

# %%
img_a[horizon_top:370, :] = gray_c[horizon_top:370, :]
img_a[370:438, :] = gray_b[370:438, :]
safe_cv2_imshow(img_a, "Three times the biggest truck", 2000)

# %%
horizon_top = 335
horizon_bottom = 709

print(f"y = {horizon_top} and y = {horizon_bottom} are considered distant 45 meters")
# Out:
# y = 335 and y = 709 are considered distant 45 meters

# %%
def find_intersection_points(line1, line2):
    x1, y1, x2, y2 = line1
    x3, y3, x4, y4 = line2
    A = np.array([
        [y2 - y1, x1 - x2],
        [y4 - y3, x3 - x4]
    ])
    b = np.array([
        [y2 * x1 - x2 * y1],
        [y4 * x3 - x4 * y3]
    ])
    try:
        intersection_point = np.linalg.solve(A, b)
        return int(intersection_point[0][0]), int(intersection_point[1][0])
    except np.linalg.LinAlgError:
        # Handle the case where lines are parallel
        return None


def find_intersections(lines, bottom_y, top_y):
    result = np.empty((len(lines), 4), dtype=int)
    
    for i, line in enumerate(lines):
        x1, y1 = find_intersection_points(line[0], (0, top_y, 100, top_y))
        x2, y2 = find_intersection_points(line[0], (0, bottom_y, 100, bottom_y))
        result[i] = np.array([x1, y1, x2, y2], dtype=int)

    return result

# %%
road_lines = find_intersections(hough_lines, bottom_y=horizon_bottom, top_y=horizon_top)

# %%
for line in road_lines:
    _, y1, _, y2 = line
    assert (y1 == horizon_top) and (y2 == horizon_bottom)

# %%
# def sort_line(line):
#     p1, p2 = line[0:2], line[2:4]
#     sorted_2d =  sorted([p1.tolist(), p2.tolist()], key=lambda x: x[1])
#     return [x for xs in sorted_2d for x in xs]

# %% [markdown]
# To determine the best value for $k$ between 3 and 8, we perform clustering with K-Means for each $k$ within this range. We then select the $k$ that yields the highest silhouette value

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

k_values = range(3, 8)

# compute silhouette coefficient foreach k value
silhouette_scores = np.empty(len(k_values), float)
for i, k in enumerate(k_values):
    kmeans = KMeans(n_clusters=k, n_init=10)
    cluster_indexes = kmeans.fit_predict(road_lines)
    silhouette_scores[i] = silhouette_score(road_lines, cluster_indexes)

# %% [markdown]
# Let's plot the results:

# %%
colors = ['blue'] * len(k_values)  # default color for all bars: blue
colors[np.argmax(silhouette_scores)] = 'red'  # color the tallest bar: red

# plot silhouette coefficients against the number of clusters
plt.bar(k_values, silhouette_scores, align='center', color=colors)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
plt.ylim(0.65, 1.0)
plt.show()

k = k_values[np.argmax(silhouette_scores)]
print('Optimal number of clusters: ', k)
# Out:
# Optimal number of clusters:  6

# %%
# initialize the KMeans object
kmeans = KMeans(n_clusters=k, init='k-means++', n_init=10)
kmeans.fit(road_lines)

# get the clusters' centroids
centroids = np.round(kmeans.cluster_centers_).astype(np.int32)

# sort centroid by intersection w/ top horizon 
centroids_sorted = sorted(centroids, key=lambda x: x[0])

# %%
def get_regions_coords(lines) -> list:
    result = []
    for i in range(0, len(lines) - 1):
        x1, y1, x2, y2 = lines[i]
        x3, y3, x4, y4 = lines[i + 1]
        region = np.array([[x1, y1], [x2, y2], [x4, y4], [x3, y3]])
        result.append(region)
    return result

polygons = get_regions_coords(centroids_sorted)

# %%
img_regions = frame

# Draw the polygons on the image
for i, poly in enumerate(polygons):
    cv2.fillPoly(img_regions, [poly], color=(255 * (i % 3 == 0), 255 * (i % 3 == 1), 255 * (i % 3 == 2)),
                 lineType=cv2.LINE_AA)
    # cv2.fillPoly(img_regions, [polygons[2]], color=(0, 255, 0), lineType=cv2.LINE_AA)

# Add transparency to the image
overlay = img_regions.copy()
opacity = 0.6
img_regions = cv2.addWeighted(overlay, opacity, frame, 1 - opacity, 0)
safe_cv2_imshow(img_regions, "Image with Polygons", 5000)

# %%
def get_inclusive_rects(rects: list, a: int, b: int) -> np.ndarray:
    """
    Given a list `rects` of rectangles and two numbers `a` and `b`, it returns the rectangle that includes all the rectangles between position `a` (included) and `b` (excluded)
    
    Args:
        rects: list of rectangles, each one of shape [4,2]
        a: index of the first rectangle to consider
        b: index of the last rectangle to consider
    """
    p0 = rects[a][0]
    p1 = rects[a][1]
    p2 = rects[b - 1][2]
    p3 = rects[b - 1][3]
    return np.asarray([p0, p1, p2, p3])

# %%
polygon_source = get_inclusive_rects(polygons, 1, 4)

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES, 335)

retval, frame_c = cap.read()
overlay = frame_c.copy()

cv2.fillPoly(frame_c, [polygon_source], color=(0, 255, 0), lineType=cv2.LINE_AA)
# Add transparency to the image
opacity = 0.6
img_reg = cv2.addWeighted(overlay, opacity, frame_c, 1 - opacity, 0, frame_c)
safe_cv2_imshow(img_reg, "f335 with Polygons ", 18000)

# %%
# enlarge the polygon zone
detection_zone = polygon_source.copy()
detection_zone[0][0] = max(polygon_source[0][0] - 100, 0)
detection_zone[1][0] = max(polygon_source[1][0] - 100, 0)
detection_zone[2][0] = min(polygon_source[2][0] + 100, IMG_WIDTH - 1)
detection_zone[3][0] = min(polygon_source[3][0] + 100, IMG_WIDTH - 1)

# %% [markdown]
# # YOLO Vehicle detection and counting

# %%
# !pip install supervision==0.18.0
# !pip install ultralytics==8.1.8
# Out:
# Requirement already satisfied: supervision==0.18.0 in ./venv/lib/python3.8/site-packages (0.18.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in ./venv/lib/python3.8/site-packages (from supervision==0.18.0) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in ./venv/lib/python3.8/site-packages (from supervision==0.18.0) (3.7.4)
# Requirement already satisfied: numpy>=1.21.2 in ./venv/lib/python3.8/site-packages (from supervision==0.18.0) (1.24.4)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in ./venv/lib/python3.8/site-packages (from supervision==0.18.0) (4.8.0.74)
# Requirement already satisfied: pyyaml>=5.3 in ./venv/lib/python3.8/site-packages (from supervision==0.18.0) (6.0.1)
# Requirement already satisfied: scipy==1.10.0 in ./venv/lib/python3.8/site-packages (from supervision==0.18.0) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.6.0->supervision==0.18.0) (6.1.1)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.6.0->supervision==0.18.0) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in ./venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->supervision==0.18.0) (3.17.0)
# Requirement already satisfied: ultralytics==8.1.8 in ./venv/lib/python3.8/site-packages (8.1.8)
# Requirement already satisfied: matplotlib>=3.3.0 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (3.7.4)
# Requirement already satisfied: numpy>=1.22.2 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (1.24.4)
# Requirement already satisfied: opencv-python>=4.6.0 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (4.7.0.72)
# Requirement already satisfied: pillow>=7.1.2 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (1.10.0)
# Requirement already satisfied: torch>=1.8.0 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (4.66.1)
# Requirement already satisfied: psutil in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (5.9.7)
# Requirement already satisfied: py-cpuinfo in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in ./venv/lib/python3.8/site-packages (from ultralytics==8.1.8) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.8) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.8/site-packages (from pandas>=1.1.4->ultralytics==8.1.8) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.8/site-packages (from pandas>=1.1.4->ultralytics==8.1.8) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics==8.1.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics==8.1.8) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics==8.1.8) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics==8.1.8) (2023.7.22)
# Requirement already satisfied: filelock in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (3.13.1)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (4.9.0)
# Requirement already satisfied: sympy in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (1.12)
# Requirement already satisfied: networkx in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (3.1)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (3.1.2)
# Requirement already satisfied: fsspec in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (2023.12.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in ./venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics==8.1.8) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./venv/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics==8.1.8) (12.3.101)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics==8.1.8) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in ./venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics==8.1.8) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.8/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.1.8) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in ./venv/lib/python3.8/site-packages (from sympy->torch>=1.8.0->ultralytics==8.1.8) (1.3.0)

# %% [markdown]
# ## DeepSORT

# %%
from statistics import mean
from typing import List

import supervision as sv

import torch
from supervision import LineZone, Point, draw_text
from ultralytics.models.yolo.detect import DetectionPredictor
from ultralytics.utils.ops import xyxy2xywh
from ultralytics.utils.plotting import Annotator, colors
from supervision.detection.core import Detections

from SpeedEstimator import SpeedEstimator
from ViewTransformer import ViewTransformer
from deep_sort_pytorch.deep_sort import DeepSort
from deep_sort_pytorch.utils.parser import get_config

# %%
SOURCE = sorted(np.array(polygon_source), key=lambda x: x[1])

SOURCE[0], SOURCE[1] = (SOURCE[0], SOURCE[1]) if SOURCE[0][0] < SOURCE[1][0] else (SOURCE[1], SOURCE[0])
SOURCE[2], SOURCE[3] = (SOURCE[2], SOURCE[3]) if SOURCE[2][0] > SOURCE[3][0] else (SOURCE[3], SOURCE[2])

SOURCE = np.array(SOURCE)

# %%
dz = sorted(np.array(detection_zone), key=lambda x: x[1])

dz[0], dz[1] = (dz[0], dz[1]) if dz[0][0] < dz[1][0] else (dz[1], dz[0])
dz[2], dz[3] = (dz[2], dz[3]) if dz[2][0] > dz[3][0] else (dz[3], dz[2])

dz = np.array(SOURCE)

# %%
print(SOURCE)
# Out:
# [[ 445  335]
#  [ 817  335]
#  [1403  709]
#  [-157  709]]

# %%
from copy import deepcopy
from collections import defaultdict

deepsort = None

CONFIDENCE_THRESHOLD = 0.3
IOU_THRESHOLD = 0.5
CLASS_ID = [2, 3, 5, 7]

video_info = sv.VideoInfo.from_video_path(video_path=SOURCE_VIDEO_PATH)
polygon = SOURCE.reshape((-1, 1, 2))
polygon_zone = sv.PolygonZone(
    polygon=SOURCE,
    frame_resolution_wh=video_info.resolution_wh
)

detection_zone = sv.PolygonZone(
    polygon=dz,
    frame_resolution_wh=video_info.resolution_wh
)

points = {
    "x1": -100. + (SOURCE[0][0] + SOURCE[3][0]) / 2.,
    "y1": (SOURCE[0][1] + SOURCE[3][1]) / 2.,
    "x2": 100. + (SOURCE[1][0] + SOURCE[2][0]) / 2.,
    "y2": (SOURCE[1][1] + SOURCE[2][1]) / 2.
}

start_point = Point(x=points["x1"], y=points["y1"])
end_point = Point(x=points["x2"], y=points["y2"])

line_counter_dict = {
    "cars": LineZone(start_point, end_point),
    "motorcycles": LineZone(start_point, end_point),
    "buses": LineZone(start_point, end_point),
    "trucks": LineZone(start_point, end_point)
}

TARGET_WIDTH = 15
TARGET_HEIGHT = 45

TARGET = np.array([
    [0, 0],
    [TARGET_WIDTH - 1, 0],
    [TARGET_WIDTH - 1, TARGET_HEIGHT - 1],
    [0, TARGET_HEIGHT - 1],
])


def init_tracker():
    global deepsort
    cfg_deep = get_config()
    cfg_deep.merge_from_file("deep_sort_pytorch/configs/deep_sort.yaml")

    deepsort = DeepSort(cfg_deep.DEEPSORT.REID_CKPT,
                        max_dist=cfg_deep.DEEPSORT.MAX_DIST, min_confidence=cfg_deep.DEEPSORT.MIN_CONFIDENCE,
                        nms_max_overlap=cfg_deep.DEEPSORT.NMS_MAX_OVERLAP,
                        max_iou_distance=cfg_deep.DEEPSORT.MAX_IOU_DISTANCE,
                        max_age=cfg_deep.DEEPSORT.MAX_AGE, n_init=cfg_deep.DEEPSORT.N_INIT,
                        nn_budget=cfg_deep.DEEPSORT.NN_BUDGET,
                        use_cuda=True)


class DeepsortPredictor(DetectionPredictor):
    speed_estimator = SpeedEstimator(trk_history=defaultdict(list), view_transformer=ViewTransformer(SOURCE, TARGET))

    def write_results(self, idx, results, batch):
        p, im, im0 = batch
        log_string = ""
        if len(im.shape) == 3:
            im = im[None]  # expand for batch dim
        frame = getattr(self.dataset, "frame", 0)

        self.data_path = p
        self.txt_path = str(self.save_dir / "labels" / p.stem) + ("" if self.dataset.mode == "image" else f"_{frame}")
        log_string += "%gx%g " % im.shape[2:]  # print string
        result = results[idx]
        log_string += result.verbose()

        im0 = im0.copy()

        detections = sv.Detections.from_ultralytics(result)
        detections = detections[polygon_zone.trigger(detections)]
        detections = detections[np.isin(detections.class_id, CLASS_ID)]
        detections = detections.with_nms(IOU_THRESHOLD)

        xywhs = torch.from_numpy(xyxy2xywh(detections.xyxy))
        confss = torch.from_numpy(detections.confidence)
        oids = detections.class_id.tolist()
        
        outputs = deepsort.update(xywhs, confss, oids, im0)  # [[x1, y1, x2, y2, track_id, track_oid],...]

        bbox_xyxy: List[List[float]] = []
        object_id: List[int] = []
        identities: List[int] = []
        
        if len(outputs) > 0:
            bbox_xyxy, identities, object_id = outputs[:, :4], outputs[:, -2], outputs[:, -1]
            tracked_detections = Detections(xyxy=bbox_xyxy, class_id=object_id, tracker_id=identities)

            # Update vehicle counting
            for i, (_, el) in enumerate(line_counter_dict.items()):
                el.trigger(tracked_detections[np.isin(tracked_detections.class_id, CLASS_ID[i])])

            # Update track_history w/ values for the current frame
            for i, track_id in enumerate(identities):
                track = self.speed_estimator.trk_history[track_id]

                bbox_bottomcenter = (mean(bbox_xyxy[i, 0:4:2]), bbox_xyxy[i][3])
                track.append(bbox_bottomcenter)
                if len(track) > 30:
                    track.pop(0)


        plot_args = {
            "names": self.model.names,
            "pred_boxes": bbox_xyxy,
            "cls_list": object_id,
            "ids": identities,
            "show_boxes": self.args.show_boxes,
            "img": im0,
            "speed_estimator": self.speed_estimator
        }

        self.plotted_img = plot(**plot_args)
        return log_string

# %%
def plot(names, pred_boxes, cls_list, ids, img=None, show_boxes=True, speed_estimator=None) -> np.ndarray:
    """
    Plots the detection results on an input RGB image. Accepts a numpy array (cv2).

    Args:
        names (List[str]): COCO's classes names
        pred_boxes (List[List[float]]): Detected boxes in the format xyxy
        ids (List[int]): Track IDs for pred_boxes
        cls_list (List[int]): List of integer representing COCO's classes for `pred_boxes`
        img (numpy.ndarray): Plot to another image. if not, plot to original image.
        show_boxes (bool): Whether to plot the bounding boxes.
        speed_estimator: `SpeedEstimator` object

    Returns:
        (numpy.ndarray): A numpy array of the annotated image.
    """
    scene = deepcopy(img)
    scene = draw_text(scene=scene, text=f"Up-wards", text_anchor=Point(x=600, y=30))
    scene = draw_text(scene=scene, text=f"Down-wards", text_anchor=Point(x=750, y=30))

    for i, (key, value) in enumerate(line_counter_dict.items()):
        scene = draw_text(scene=scene, text=f"{key}: {value.out_count}", text_anchor=Point(x=600, y=50 + 20 * i))
        scene = draw_text(scene=scene, text=f"{key}: {value.in_count}", text_anchor=Point(x=750, y=50 + 20 * i))

    annotator = Annotator(scene, font="Arial.ttf")
    annotator.sf = 0.5
    annotator.tf = 1
    annotator.draw_region(polygon)

    i = len(pred_boxes) - 1

    if pred_boxes is not None and show_boxes:
        for d in reversed(pred_boxes):
            c = int(cls_list[i])
            id = int(ids[i])

            label = ("" if id is None else f"id:{id} ") + names[c]
            box = d.squeeze()
            if speed_estimator is not None:
                annotator.draw_centroid_and_tracks(speed_estimator.trk_history[id])
                if len(speed_estimator.trk_history[id]) >= 15:
                    speed, error = speed_estimator.estimate_speed(id)
                    label += f" {int(speed)}+-{error:.1f} kmh"  # ±

            annotator.box_label(box, label, color=colors(c, True), rotated=False)
            i -= 1

    annotator.draw_region(  # detection lines
        reg_pts=[[int(points["x1"]), int(points["y1"])], [int(points["x2"]), int(points["y2"])]],
        color=(255, 255, 0),
        thickness=1
    )

    return annotator.result()

# %%
def predict(model, source) -> None:
    init_tracker()
    video_info = sv.VideoInfo.from_video_path(video_path=source)
    global polygon_zone
    polygon_zone = sv.PolygonZone(
        polygon=SOURCE,
        frame_resolution_wh=video_info.resolution_wh
    )
    args = dict(model=model, source=source)
    predictor = DeepsortPredictor(overrides=args)
    predictor()


predict(model='yolov8s.pt', source="./test15.mp4")
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.8.18 torch-2.1.2+cu121 CPU (AMD Ryzen 5 3600 6-Core Processor)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# video 1/1 (1/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 7 cars, 1 train, 3 trucks, 717.1ms
# video 1/1 (2/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 5 cars, 1 train, 3 trucks, 99.7ms
# video 1/1 (3/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 5 cars, 1 train, 3 trucks, 103.7ms
# video 1/1 (4/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 8 cars, 1 train, 3 trucks, 86.9ms
# video 1/1 (5/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 134.0ms
# video 1/1 (6/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 100.3ms
# video 1/1 (7/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 116.7ms
# video 1/1 (8/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 96.5ms
# video 1/1 (9/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 127.2ms
# video 1/1 (10/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 117.5ms
# video 1/1 (11/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 128.0ms
# video 1/1 (12/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 121.9ms
# video 1/1 (13/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 116.7ms
# video 1/1 (14/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 125.6ms
# video 1/1 (15/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 121.8ms
# video 1/1 (16/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 115.6ms
# video 1/1 (17/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 bus, 1 train, 3 trucks, 112.2ms
# video 1/1 (18/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 122.5ms
# video 1/1 (19/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 4 trucks, 127.4ms
# video 1/1 (20/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 4 trucks, 117.6ms
# video 1/1 (21/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 4 trucks, 117.3ms
# video 1/1 (22/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 4 trucks, 127.8ms
# video 1/1 (23/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 4 trucks, 105.2ms
# video 1/1 (24/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 4 trucks, 123.1ms
# video 1/1 (25/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 101.3ms
# video 1/1 (26/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 8 cars, 1 train, 3 trucks, 116.5ms
# video 1/1 (27/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 8 cars, 1 train, 3 trucks, 122.7ms
# video 1/1 (28/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 7 cars, 1 train, 3 trucks, 116.4ms
# video 1/1 (29/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 8 cars, 1 train, 4 trucks, 124.5ms
# video 1/1 (30/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 7 cars, 1 train, 4 trucks, 119.7ms
# video 1/1 (31/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 125.7ms
# video 1/1 (32/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 bus, 1 train, 3 trucks, 119.9ms
# video 1/1 (33/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 121.2ms
# video 1/1 (34/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 120.7ms
# video 1/1 (35/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 114.3ms
# video 1/1 (36/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 115.7ms
# video 1/1 (37/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 95.2ms
# video 1/1 (38/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 117.0ms
# video 1/1 (39/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 100.3ms
# video 1/1 (40/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 3 trucks, 117.6ms
# video 1/1 (41/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 110.3ms
# video 1/1 (42/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 126.5ms
# video 1/1 (43/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 99.8ms
# video 1/1 (44/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 103.7ms
# video 1/1 (45/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 128.1ms
# video 1/1 (46/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 2 trucks, 124.3ms
# video 1/1 (47/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 bus, 1 train, 2 trucks, 100.4ms
# video 1/1 (48/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 118.6ms
# video 1/1 (49/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 8 cars, 1 train, 3 trucks, 112.5ms
# video 1/1 (50/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 103.3ms
# video 1/1 (51/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 120.1ms
# video 1/1 (52/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 118.5ms
# video 1/1 (53/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 125.0ms
# video 1/1 (54/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 8 cars, 1 train, 3 trucks, 113.2ms
# video 1/1 (55/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 113.8ms
# video 1/1 (56/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 96.0ms
# video 1/1 (57/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 97.6ms
# video 1/1 (58/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 105.7ms
# video 1/1 (59/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 4 trucks, 111.4ms
# video 1/1 (60/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 100.0ms
# video 1/1 (61/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 97.6ms
# video 1/1 (62/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 80.8ms
# video 1/1 (63/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 90.4ms
# video 1/1 (64/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 96.2ms
# video 1/1 (65/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 115.0ms
# video 1/1 (66/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 2 trucks, 87.5ms
# video 1/1 (67/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 114.3ms
# video 1/1 (68/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 2 trucks, 101.5ms
# video 1/1 (69/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 99.6ms
# video 1/1 (70/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 93.5ms
# video 1/1 (71/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 119.1ms
# video 1/1 (72/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 74.7ms
# video 1/1 (73/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 2 trucks, 91.0ms
# video 1/1 (74/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 100.6ms
# video 1/1 (75/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 115.0ms
# video 1/1 (76/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 97.3ms
# video 1/1 (77/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 94.1ms
# video 1/1 (78/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 77.9ms
# video 1/1 (79/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 91.2ms
# video 1/1 (80/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 114.4ms
# video 1/1 (81/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 82.0ms
# video 1/1 (82/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 79.7ms
# video 1/1 (83/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 82.9ms
# video 1/1 (84/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 99.2ms
# video 1/1 (85/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 76.0ms
# video 1/1 (86/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 106.0ms
# video 1/1 (87/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 105.5ms
# video 1/1 (88/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 95.6ms
# video 1/1 (89/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 99.4ms
# video 1/1 (90/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 94.1ms
# video 1/1 (91/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 9 cars, 1 train, 3 trucks, 102.7ms
# video 1/1 (92/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 92.9ms
# video 1/1 (93/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 119.4ms
# video 1/1 (94/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 97.2ms
# video 1/1 (95/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 117.3ms
# video 1/1 (96/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 97.4ms
# video 1/1 (97/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 3 trucks, 168.8ms
# video 1/1 (98/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 103.1ms
# video 1/1 (99/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 106.0ms
# video 1/1 (100/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 102.0ms
# video 1/1 (101/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 87.4ms
# video 1/1 (102/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 102.2ms
# video 1/1 (103/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 118.3ms
# video 1/1 (104/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 80.6ms
# video 1/1 (105/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 88.6ms
# video 1/1 (106/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 111.7ms
# video 1/1 (107/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 2 trucks, 108.9ms
# video 1/1 (108/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 2 trucks, 86.3ms
# video 1/1 (109/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 81.6ms
# video 1/1 (110/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 85.0ms
# video 1/1 (111/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 89.6ms
# video 1/1 (112/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 110.1ms
# video 1/1 (113/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 113.3ms
# video 1/1 (114/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 129.1ms
# video 1/1 (115/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 99.4ms
# video 1/1 (116/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 10 cars, 1 train, 3 trucks, 77.0ms
# video 1/1 (117/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 79.7ms
# video 1/1 (118/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 116.1ms
# video 1/1 (119/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 76.7ms
# video 1/1 (120/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 4 trucks, 112.4ms
# video 1/1 (121/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 4 trucks, 100.0ms
# video 1/1 (122/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 98.4ms
# video 1/1 (123/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 95.6ms
# video 1/1 (124/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 110.5ms
# video 1/1 (125/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 1 truck, 109.6ms
# video 1/1 (126/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 2 trucks, 85.8ms
# video 1/1 (127/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 90.9ms
# video 1/1 (128/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 129.9ms
# video 1/1 (129/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 96.8ms
# video 1/1 (130/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 3 trucks, 101.1ms
# video 1/1 (131/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 3 trucks, 100.9ms
# video 1/1 (132/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 80.1ms
# video 1/1 (133/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 96.2ms
# video 1/1 (134/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 3 trucks, 78.3ms
# video 1/1 (135/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 3 trucks, 85.4ms
# video 1/1 (136/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 82.7ms
# video 1/1 (137/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 3 trucks, 101.9ms
# video 1/1 (138/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 99.9ms
# video 1/1 (139/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 78.4ms
# video 1/1 (140/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 90.9ms
# video 1/1 (141/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 83.0ms
# video 1/1 (142/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 109.5ms
# video 1/1 (143/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 95.6ms
# video 1/1 (144/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 116.3ms
# video 1/1 (145/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 11 cars, 1 train, 4 trucks, 125.5ms
# video 1/1 (146/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 121.2ms
# video 1/1 (147/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 106.8ms
# video 1/1 (148/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 13 cars, 1 train, 2 trucks, 78.2ms
# video 1/1 (149/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 3 trucks, 98.2ms
# video 1/1 (150/150) /home/lucav/Documents/Master/vcs/project/test15.mp4: 384x640 12 cars, 1 train, 2 trucks, 106.4ms
# Speed: 13.5ms preprocess, 109.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train366

# %% [markdown]
# ## ByteTrack

# %%
from collections import deque
from ultralytics import YOLO

TARGET_VIDEO_PATH = SOURCE_FOLDER + "/result_tst1.mp4"

MODEL_NAME = "yolov8s.pt"
MODEL_RESOLUTION = 1000
from SpeedEstimator import SpeedEstimator
from ViewTransformer import ViewTransformer


width = video_info.width
height = video_info.height



line_counter_dict = {

    "cars": LineZone(start_point, end_point),
    "motorcycles": LineZone(start_point, end_point),
    "buses": LineZone(start_point, end_point),
    "trucks": LineZone(start_point, end_point)
}

LINE_COUNT = np.array([
    [int(points["x1"]), int(points["y1"])],
    [int(points["x2"]), int(points["y2"])]
]).reshape((2, 2))


model = YOLO(MODEL_NAME)

frame_generator = sv.get_video_frames_generator(source_path=SOURCE_VIDEO_PATH)

# tracer initiation
byte_track = sv.ByteTrack(frame_rate=video_info.fps, track_thresh=CONFIDENCE_THRESHOLD)

# annotators configuration
thickness = sv.calculate_dynamic_line_thickness(resolution_wh=video_info.resolution_wh)
text_scale = sv.calculate_dynamic_text_scale(resolution_wh=video_info.resolution_wh)
bounding_box_annotator = sv.BoundingBoxAnnotator(thickness=thickness)

label_annotator = sv.LabelAnnotator(
    text_scale=text_scale,
    text_thickness=thickness,
    text_position=sv.Position.BOTTOM_CENTER
)

trace_annotator = sv.TraceAnnotator(
    thickness=thickness,
    trace_length=video_info.fps * 2,
    position=sv.Position.BOTTOM_CENTER
)

polygon_zone = sv.PolygonZone(
    polygon=SOURCE,
    frame_resolution_wh=video_info.resolution_wh
)

coordinates = defaultdict(lambda: deque(maxlen=video_info.fps))
speed_estimator = SpeedEstimator(defaultdict(list), ViewTransformer(SOURCE, TARGET))


with sv.VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    for frame in tqdm(frame_generator, total=video_info.total_frames):

        result = model(frame, imgsz=640, verbose=False)[0]
        detections = sv.Detections.from_ultralytics(result)

        detections = detections[detections.confidence > CONFIDENCE_THRESHOLD]
        detections = detections[np.isin(detections.class_id, CLASS_ID)]
        detections = detections[polygon_zone.trigger(detections)]
        detections = detections.with_nms(IOU_THRESHOLD)

        # pass detection through the tracker
        detections = byte_track.update_with_detections(detections=detections)
        points = detections.get_anchors_coordinates(anchor=sv.Position.BOTTOM_CENTER)

        # calculate the detections position inside the target RoI
        transformed_points = speed_estimator.view_transformer.transform_points(points=points).astype(int)

        # store detections position
        for tracker_id, [_, y] in zip(detections.tracker_id, transformed_points):
            coordinates[tracker_id].append(y)

        for tracker_id, [x, y] in zip(detections.tracker_id, points):
            track = speed_estimator.trk_history[tracker_id]

            bbox_bottomcenter = (x, y)
            track.append(bbox_bottomcenter)
            if len(track) > 30:
                track.pop(0)
        # format labels
        labels = []

        for i, (key, el) in enumerate(line_counter_dict.items()):
            el.trigger(detections[np.isin(detections.class_id, CLASS_ID[i])])

        for tracker_id in detections.tracker_id:
            if len(coordinates[tracker_id]) < video_info.fps / 2:
                labels.append(f"#{tracker_id}")
            else:

                speed, error = speed_estimator.estimate_speed(tracker_id, video_info.fps)
                labels.append(f" {int(speed)}+-{error:.1f} kmh")  # ±

        annotated_frame = frame.copy()
        annotated_frame = trace_annotator.annotate(annotated_frame, detections)
        annotated_frame = bounding_box_annotator.annotate(annotated_frame, detections)
        annotated_frame = label_annotator.annotate(annotated_frame, detections, labels)
        
        annotated_frame = draw_text(scene=annotated_frame, text=f"Up-wards", text_anchor=Point(x=600, y=30))
        annotated_frame = draw_text(scene=annotated_frame, text=f"Down-wards", text_anchor=Point(x=750, y=30))
        for i, (key, value) in enumerate(line_counter_dict.items()):
            annotated_frame = draw_text(scene=annotated_frame, text=f"{key}: {value.out_count}",
                                        text_anchor=Point(x=600, y=50 + 20 * i))
            annotated_frame = draw_text(scene=annotated_frame, text=f"{key}: {value.in_count}",
                                        text_anchor=Point(x=750, y=50 + 20 * i))

        cv2.polylines(annotated_frame, [polygon], True, (0, 255, 0), thickness=1)
        cv2.line(annotated_frame,
                 (int(-50. + (SOURCE[0][0] + SOURCE[3][0]) / 2.), int((SOURCE[0][1] + SOURCE[3][1]) / 2.)),
                 (int(50. + (SOURCE[1][0] + SOURCE[2][0]) / 2.), int((SOURCE[1][1] + SOURCE[2][1]) / 2.)),
                 (255, 0, 0), thickness=1)

        sink.write_frame(annotated_frame)
# Out:
#   0%|          | 0/942 [00:00<?, ?it/s]
